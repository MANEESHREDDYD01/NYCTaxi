# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import pandas as pd

from src.config import TRANSFORMED_DATA_DIR

features_and_targets = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")

# %%
features = features_and_targets.iloc[:, :-1]
targets = features_and_targets["target"]

# %%
filtered_data = features[features['pickup_location_id'] == 43]
print(filtered_data)
# Out:
#        rides_t-672  rides_t-671  rides_t-670  rides_t-669  rides_t-668  \
# 13817           92           81           29           15            4
# 13818            2            0            2            2            0
# 13819            1            0            0            0            1
# 13820            3            2            0            0            1
# 13821            6            0            0            1            0
# ...            ...          ...          ...          ...          ...
# 14149            3            0            1            0            1
# 14150            6            2            2            0            1
# 14151           20            7            2            0            3
# 14152           10            8            3            1            3
# 14153           19           10            1            2            2
#
#        rides_t-667  rides_t-666  rides_t-665  rides_t-664  rides_t-663  ...  \
# ...

# %%
target_value = targets.iloc[3772]  # Accessing target for row with index 3772
print(target_value)
# Out:
# 2

# %%
feature_row = features.iloc[3772]
print(feature_row)
# Out:
# rides_t-672                             2
# rides_t-671                             1
# rides_t-670                             0
# rides_t-669                             0
# rides_t-668                             1
#                              ...
# rides_t-3                              20
# rides_t-2                               6
# rides_t-1                               1
# pickup_hour           2023-04-04 00:00:00
# pickup_location_id                     13
# Name: 3772, Length: 674, dtype: object

# %%
from src.plot_utils import plot_aggregated_time_series

# Verify the feature_row and target_value before passing them to the plot function
print(f"Feature row (type): {type(feature_row)}")
print(f"Feature row (head): {feature_row.head() if isinstance(feature_row, pd.Series) else 'Not a Series'}")
print(f"Target value (type): {type(target_value)}")

# Try calling the plot function with the relevant parameters
try:
    plot_aggregated_time_series(feature_row, target_value, row_id=3772)
except Exception as e:
    print(f"Error during plotting: {e}")
# Out:
# Feature row (type): <class 'pandas.core.series.Series'>
# Feature row (head): rides_t-672    2
# rides_t-671    1
# rides_t-670    0
# rides_t-669    0
# rides_t-668    1
# Name: 3772, dtype: object
# Target value (type): <class 'numpy.int16'>
# Error during plotting: single positional indexer is out-of-bounds

# %%
from src.plot_utils import plot_aggregated_time_series

# Ensure we're passing data in the expected format
feature_row_df = features.loc[[3772]]  # Convert the feature row to a DataFrame
target_value = targets.iloc[3772]     # Keep the target value as is

# Call the plot function with the correct format
try:
    plot_aggregated_time_series(feature_row_df, target_value, row_id=3772)
except Exception as e:
    print(f"Error during plotting: {e}")
# Out:
# Error during plotting: single positional indexer is out-of-bounds

# %%
from src.plot_utils import plot_aggregated_time_series

# Define the row_id explicitly (for example, using 3772)
row_id = 3772

# Extracting the relevant row for the given row_id from features and targets
feature_row = features.iloc[row_id]  # Get the row from features
target_value = targets.iloc[row_id]  # Get the corresponding target value

# Plot the aggregated time series for this row
plot_aggregated_time_series(features, targets, row_id=row_id)
